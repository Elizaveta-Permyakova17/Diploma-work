# %% [markdown]
# \begin{equation}
# \pdv{U}{t}=\kappa(U_0-U)-\frac{\alpha U C_1}{1+b_1C_1}
# \end{equation}
# \begin{equation}
# \pdv{I}{t}=\frac{\alpha U C_1}{1+b_1C_1}-\beta I
# \end{equation}
# \begin{equation}
# \pdv{C_1}{t}=d_{C_1}\pdv[{2}]{C_1}{x}+\frac{a_1C_1M_1}{1+b_2C_1+d_1C_2}+\frac{k_1I}{1+d_2C_2}-\gamma_1 C_1
# \end{equation}
# \begin{equation}
# \pdv{M_1}{t}=d_{M_1}\pdv[{2}]{M_1}{x}+\frac{a_3C_1}{1+b_3C_1}-\gamma_3 M_1
# \end{equation}

# %% [markdown]
# ## Implicit

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Parameters of the model
kappa = 0.1
alpha = 0.2
B1 = 0.4
b2 = 0.4
b3 = 0.4
A1 = 0.1
k1 = 0.5
g1 = 0.2
g3 = 0.2
U0 = 2.0

beta = 0.7
a3 = 0.55

D_C1 = 10**(-4)
D_M1 = 10**(-4)

# %%
#Initial conditions
U_0 = 2.0
I_0 = 0.0
M1_0 = 0.5
C1_0 = 0.08

# %%
M = 4000 #space partitioning
T = 1000
L  = 4
h = L/M  #space step

tau = 0.1
N = int(T/tau) #time partitioning

#N = 9000
#tau = T/N

x = np.linspace(0, L, M+1)
t = np.linspace(0, T, N+1)

# %%
M
# Out:
# 4000

# %%
h
# Out:
# 0.001

# %%
U = np.zeros([N+1, M+1])
I = np.zeros([N+1, M+1])
C1 = np.zeros([N+1, M+1])
M1 = np.zeros([N+1, M+1])

# %%
U[0,:] = U_0
I[0,:] = I_0
M1[0] = np.ones(M + 1) * M1_0
M1[0, 401::] = 0
plt.plot(x, M1[0])
plt.show()

# %%
C1[0] = np.ones(M + 1) * C1_0
C1[0, 401::] = 0
plt.plot(x, C1[0])
plt.show()

# %%
# a - lower diag, b - main diag, c - upper diag, d - sol

def Thomas_Method(a, b, c, d):
    n = len(a)
    res = np.zeros(n)

    w = np.zeros(n - 1)
    g = np.zeros(n)

    w[0] = c[0]/b[0] # c'_1
    g[0] = d[0]/b[0] # d'_1

    for i in range(1, n - 1):
        w[i] = c[i] / (b[i] - a[i] * w[i - 1])
        g[i] = (d[i] - a[i]* g[i - 1]) / (b[i] - \
                                                      a[i] * w[i - 1])

    g[n - 1] = (d[n - 1] - a[n - 1]* g[n - 2]) / (b[n - 1] - \
                                                     a[n - 1] * w[n - 2])
    res[n - 1] = g[n - 1]
    for i in range(n - 2, -1, -1 ):
        res[i] = g[i] - w[i] * res[i + 1]
    return res

# %%
s1 = (D_C1*tau)/(h**2)
s2 = (D_M1*tau)/(h**2)

# %%
for i in range(1, N+1):
    a = np.zeros(M+1)
    b = np.zeros(M+1)
    c = np.zeros(M+1)
    d = np.zeros(M+1)
    a[0] = 0
    a[1:M+1] = -s1
    b[0] = 1 +s1
    b[1:M] = 1 + 2*s1
    b[M] = 1+s1
    c[0:M] = -s1
    c[M] = 0
    d[0:M+1] = (tau*A1*C1[i-1,0:M+1]*M1[i-1,0:M+1])/(1+b2*C1[i-1,0:M+1]) + tau*k1*I[i-1,0:M+1] + (1 -tau*g1)*C1[i-1,0:M+1]

    a1 = np.zeros(M+1)
    b1 = np.zeros(M+1)
    c1 = np.zeros(M+1)
    d1 = np.zeros(M+1)
    a1[0] = 0
    a1[1:M+1]= -s2
    b1[0] =1 + s2
    b1[1:M] = 1 + 2*s2
    b[M] = 1+s2
    c1[0:M]=  -s2
    c1[M]= 0
    d1[0:M+1] = (tau*a3*C1[i-1,0:M+1])/(1+b3*C1[i-1,0:M+1])  + (1 - tau*g3)*M1[i-1,0:M+1]

    C1[i] = Thomas_Method(a, b, c, d)
    M1[i] = Thomas_Method(a1, b1, c1, d1)
    U[i]=kappa*tau*U_0 + (1-kappa*tau)*U[i-1]-tau*(alpha*U[i-1]*C1[i-1])/(1+B1*C1[i-1])
    I[i]=tau*(alpha*U[i-1]*C1[i-1])/(1+B1*C1[i-1]) + (1-beta*tau)*I[i-1]

# %%
u=np.zeros(M+1)
for i in range(0, M+1):
  u[i]=U[N,0]

infl=np.zeros(M+1)
for i in range(0, M+1):
  infl[i]=I[N,0]

cyt=np.zeros(M+1)
for i in range(0, M+1):
  cyt[i]=C1[N,0]

mak=np.zeros(M+1)
for i in range(0, M+1):
  mak[i]=M1[N,0]

# %%
U12=np.zeros(M+1)
for i in range(0, M+1):
  U12[i]=1.20000

# %%
plt.style.use('seaborn-white')
plt.figure(figsize=(12,6))
#plt.title("Concentration of uninfected cells at different time points")

for i in range(0, N,N//5):
    plt.plot(x, U[i], c = "blue", label = t[i])

plt.plot(x, U[0], c = "black")

plt.plot(x, u, c = "red")

plt.plot(x, U12, c = "green")

plt.xlabel('$x$')
plt.ylabel('$u(x,t)$')
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_3780\3046450638.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
I01=np.zeros(M+1)
for i in range(0, M+1):
  I01[i]=0.1

# %%
plt.style.use('seaborn-white')
plt.figure(figsize=(12,6))
#plt.title("Concentration of infected cells of the circuit at different time points")

for i in range(0, N,N//5):
    plt.plot(x, I[i], c = "blue", label = t[i])

plt.plot(x, I[0], c = "black")

plt.plot(x, infl, c = "red")

plt.plot(x, I01, c = "green")

plt.xlabel('$x$')
plt.ylabel('$I(x,t)$')
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_3780\3373627384.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
C15=np.zeros(M+1)
for i in range(0, M+1):
  C15[i]=1.5

# %%
plt.style.use('seaborn-white')
plt.figure(figsize=(12,6))
#plt.title("Cytokines concentration at different time points")

for i in range(0, N,N//5):
    plt.plot(x, C1[i], c = "blue", label = t[i])

plt.plot(x, C1[0], c = "black")

plt.plot(x, cyt, c = "red")

plt.plot(x, C15, c = "green")


plt.xlabel('$x$')
plt.ylabel('$C1(x,t)$')
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_3780\4279148448.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
M20=np.zeros(M+1)
for i in range(0, M+1):
  M20[i]=2.0

# %%
plt.style.use('seaborn-white')
plt.figure(figsize=(12,6))
#plt.title("Macrophages concentration at different time points")

for i in range(0, N, N//5):
    plt.plot(x, M1[i], c = "blue", label = t[i])

plt.plot(x, M1[0], c = "black")

plt.plot(x, mak, c = "red")

plt.plot(x, M20, c = "green")

plt.xlabel('$x$')
plt.ylabel('$M1(x,t)$')
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_3780\1825422729.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')
